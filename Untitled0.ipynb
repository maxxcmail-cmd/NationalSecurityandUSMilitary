# %% [markdown]
# <a href="https://colab.research.google.com/github/maxxcmail-cmd/NationalSecurityandUSMilitary/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv("areas_transfers_clean.csv")
df.head()
